# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
print("Average final grade:", df["G3"].mean())
print("Highest final grade:", df["G3"].max())
print("Lowest final grade:", df["G3"].min())
# Out:
# Average final grade: 10.415189873417722
# Highest final grade: 20
# Lowest final grade: 0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    str
#  1   sex         395 non-null    str
#  2   age         395 non-null    int64
#  3   address     395 non-null    str
#  4   famsize     395 non-null    str
#  5   Pstatus     395 non-null    str
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    str
#  9   Fjob        395 non-null    str
#  10  reason      395 non-null    str
#  11  guardian    395 non-null    str
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    str
#  16  famsup      395 non-null    str
#  17  paid        395 non-null    str
#  18  activities  395 non-null    str
#  19  nursery     395 non-null    str
# ...

# %%
plt.figure(figsize=(8, 5))

plt.hist(df["G3"], bins=20)

plt.xlabel("Final Grade (G3)")
plt.ylabel("Number of Students")
plt.title("Distribution of Student Final Grades")

plt.show()

# %%
study_grade = df.groupby("studytime")["G3"].mean()

print(study_grade)
# Out:
# studytime
# 1    10.047619
# 2    10.171717
# 3    11.400000
# 4    11.259259
# Name: G3, dtype: float64

# %%
print("Rows and columns:", df.shape)
# Out:
# Rows and columns: (395, 33)

# %%
plt.figure(figsize=(8, 5))

plt.bar(study_grade.index, study_grade.values)

plt.xlabel("Study Time")
plt.ylabel("Average Final Grade (G3)")
plt.title("Study Time vs Final Grade")

plt.show()

# %%
df = pd.read_csv("../student-mat.csv", sep=";")
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
failure_grade = df.groupby("failures")["G3"].mean()

print(failure_grade)
# Out:
# failures
# 0    11.253205
# 1     8.120000
# 2     6.235294
# 3     5.687500
# Name: G3, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 5))

plt.bar(failure_grade.index, failure_grade.values)

plt.xlabel("Number of Previous Failures")
plt.ylabel("Average Final Grade (G3)")
plt.title("Previous Failures vs Final Grade")

plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.scatter(df["absences"], df["G3"])

plt.xlabel("Number of Absences")
plt.ylabel("Final Grade (G3)")
plt.title("Absences vs Final Grade")

plt.show()

# %%
correlation = df["absences"].corr(df["G3"])

print("Correlation between absences and final grade:", correlation)
# Out:
# Correlation between absences and final grade: 0.03424731615006934

# %%
gender_grade = df.groupby("sex")["G3"].mean()

print(gender_grade)
# Out:
# sex
# F     9.966346
# M    10.914439
# Name: G3, dtype: float64

# %%
plt.figure(figsize=(7, 5))

plt.bar(gender_grade.index, gender_grade.values)

plt.xlabel("Gender")
plt.ylabel("Average Final Grade (G3)")
plt.title("Gender vs Final Grade")

plt.show()

# %%
parent_grade = df.groupby("Medu")["G3"].mean()

print(parent_grade)
# Out:
# Medu
# 0    13.000000
# 1     8.677966
# 2     9.728155
# 3    10.303030
# 4    11.763359
# Name: G3, dtype: float64

# %%
plt.figure(figsize=(8, 5))

plt.bar(parent_grade.index, parent_grade.values)

plt.xlabel("Mother's Education Level")
plt.ylabel("Average Final Grade (G3)")
plt.title("Mother's Education vs Final Grade")

plt.show()

# %%
correlations = df[["studytime", "failures", "absences", "G1", "G2", "G3"]].corr()

print(correlations["G3"].sort_values(ascending=False))
# Out:
# G3           1.000000
# G2           0.904868
# G1           0.801468
# studytime    0.097820
# absences     0.034247
# failures    -0.360415
# Name: G3, dtype: float64

# %%
plt.figure(figsize=(8, 5))

correlations["G3"].drop("G3").sort_values().plot(kind="barh")

plt.xlabel("Correlation with Final Grade (G3)")
plt.ylabel("Factor")
plt.title("Factors Related to Final Grade")

plt.show()

# %%
df = pd.read_csv("../data/student-mat.csv", sep=";")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df = pd.read_csv("../data/student-mat.csv", sep=";")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...
